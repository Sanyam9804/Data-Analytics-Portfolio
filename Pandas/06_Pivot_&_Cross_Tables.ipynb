# %%
import pandas as pd
import numpy as np

# Create sample data
data = {
    'Date': pd.date_range('2023-01-01', periods=10),
    'Product': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C', 'A'],
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West'],
    'Sales': np.random.randint(100, 1000, 10)
}

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Create new column Month from Date
df['Month'] = df['Date'].dt.month_name()

# %%
df
# Out:
#         Date Product Region  Sales    Month
# 0 2023-01-01       A   East    675  January
# 1 2023-01-02       B   West    410  January
# 2 2023-01-03       C  North    672  January
# 3 2023-01-04       A  South    389  January
# 4 2023-01-05       B   East    284  January
# 5 2023-01-06       C   West    291  January
# 6 2023-01-07       A  North    326  January
# 7 2023-01-08       B  South    430  January
# 8 2023-01-09       C   East    281  January
# 9 2023-01-10       A   West    348  January

# %%
# 🔥 Pivot Table
pivot = pd.pivot_table(
    df,
    values='Sales',        # Column to aggregate -> in this i use sum 
    index='Product',       # Rows                                  |
    columns='Region',      # Columns                               V
    aggfunc='sum'          # Aggregation function ------------------
)

print("PIVOT TABLE:\n")
print(pivot)
# Out:
# PIVOT TABLE:
#
# Region    East  North  South   West
# Product
# A        675.0  326.0  389.0  348.0
# B        284.0    NaN  430.0  410.0
# C        281.0  672.0    NaN  291.0

# %%
# CROSS TABLE

pd.crosstab(df['Product'],df)
